# %% [markdown]
# # Capstone Exploration
# ### by Jan Allen Pasia

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
prices_df = pd.read_csv('data/damarketprices2013.csv')
prices_df
# Out:
#             date                         name_of_market  \
# 0     11/11/2013  Batangas City Public Market, Batangas
# 1     11/11/2013  Batangas City Public Market, Batangas
# 2     11/11/2013  Batangas City Public Market, Batangas
# 3     11/11/2013  Batangas City Public Market, Batangas
# 4     11/11/2013  Batangas City Public Market, Batangas
# ...          ...                                    ...
# 2172   2/11/2013              Mandaluyong Public Market
# 2173   2/11/2013              Mandaluyong Public Market
# 2174   2/11/2013              Mandaluyong Public Market
# 2175   2/12/2013              Mandaluyong Public Market
# 2176   2/13/2013              Mandaluyong Public Market
#
#                                                comodity  price/kg.
# 0                                Ampalaya Fruit, Medium       50.0
# 1                                        Bangus, Medium      140.0
# 2                                           Blackpepper      320.0
# ...

# %%
mrt12_df = pd.read_csv('data/2012_mrt_hourly_daily_ridership 2.csv')
mrt12_df.head(30)
# Out:
#        month  day           time north_avenue_entry north_avenue_exit  \
# 0   January     1  03:00 - 03:59                  -                 -
# 1   January     1  04:00 - 04:59                  -                 -
# 2   January     1  05:00 - 05:59                  -                 -
# 3   January     1  06:00 - 06:59                220                 -
# 4   January     1  07:00 - 07:59                702               336
# 5   January     1  08:00 - 08:59               1019               613
# 6   January     1  09:00 - 09:59               1345               706
# 7   January     1  10:00 - 10:59               2282              1097
# 8   January     1  11:00 - 11:59               2722              1680
# 9   January     1  12:00 - 12:59               2383              1837
# 10  January     1  13:00 - 13:59               2176              1510
# 11  January     1  14:00 - 14:59               2145              1698
# ...

# %%
mrt12_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                8784 non-null   object
#  1   day                  8784 non-null   int64
#  2   time                 8784 non-null   object
#  3   north_avenue_entry   8784 non-null   object
#  4   north_avenue_exit    8784 non-null   object
#  5   quezon_avenue_entry  8784 non-null   object
#  6   quezon_avenue_exit   8784 non-null   object
#  7   gma_kamuning_entry   8784 non-null   object
#  8   gma_kamuning_exit    8784 non-null   object
#  9   cubao_entry          8784 non-null   object
#  10  cubao_exit           8784 non-null   object
#  11  santolan_entry       8784 non-null   object
#  12  santolan_exit        8784 non-null   object
#  13  ortigas_entry        8784 non-null   object
#  14  ortigas_exit         8784 non-null   object
# ...

# %%
mrt13_df = pd.read_csv('data/2013_mrt_hourly_daily_ridership.csv')
mrt13_df.head(30)
# Out:
#       month  day           time north_avenue_entry north_avenue_exit  \
# 0   January  1.0  03:00 - 03:59                  -                 -
# 1   January  1.0  04:00 - 04:59                  -                 -
# 2   January  1.0  05:00 - 05:59                367                94
# 3   January  1.0  06:00 - 06:59                533               610
# 4   January  1.0  07:00 - 07:59                678               800
# 5   January  1.0  08:00 - 08:59                759               930
# 6   January  1.0  09:00 - 09:59               1089              1236
# 7   January  1.0  10:00 - 10:59               1972              1694
# 8   January  1.0  11:00 - 11:59               2513              2383
# 9   January  1.0  12:00 - 12:59               2064              2256
# 10  January  1.0  13:00 - 13:59               1607              2030
# 11  January  1.0  14:00 - 14:59               1586              2457
# 12  January  1.0  15:00 - 15:59               2237              2908
# ...

# %%
ridership_df = pd.read_csv('data/2017_MRT3_Ridership_by_Station_0.csv')
ridership_df.head(30)
# Out:
#         Month        Station      Entry       Exit
# 0     January   North Avenue  2,171,030  1,251,125
# 1    February   North Avenue  1,974,639  1,173,156
# 2       March   North Avenue  2,171,175  1,273,263
# 3       April   North Avenue  1,718,961  1,014,983
# 4         May   North Avenue  2,063,065  1,203,944
# 5        June   North Avenue  1,879,943  1,121,954
# 6        July   North Avenue  2,020,455  1,213,438
# 7      August   North Avenue  2,082,851  1,237,564
# 8   September   North Avenue  1,988,894  1,205,595
# 9     October   North Avenue  2,073,588  1,242,960
# 10   November   North Avenue  1,788,670  1,080,852
# 11   December   North Avenue  1,844,986  1,119,271
# 12    January  Quezon Avenue    975,489    864,427
# 13   February  Quezon Avenue    900,077    827,374
# 14      March  Quezon Avenue  1,004,008    914,923
# 15      April  Quezon Avenue    769,945    697,407
# 16        May  Quezon Avenue    925,970    838,516
# ...

# %%
puj_df = pd.read_csv('data/Road_LTFRB_CO_PUJ_Routes_Units.csv')
puj_df.head(30)
# Out:
#                                   Route_Name  Franchise_Count  \
# 0   Alabang - Baclaran viaSn Dionisio,Zapote                1
# 1                         Alabang - Balibago               42
# 2   Alabang - Balibago Sta Rosa Lag. via SSH               71
# 3            Alabang - BiNan via National Rd              202
# 4          Alabang - Calamba via National Rd              204
# 5                          Alabang - Carmona               72
# 6                  Alabang - Carmona Bulihan                6
# 7                  Alabang - Carmona to Buhi                1
# 8           Alabang - Carmona via Expressway               19
# 9      Alabang - GMA Alab Carmona to Bulihan                1
# 10     Alabang - GMA via Carmona, Expressway               65
# 11       Alabang - GMA via Carmona, Nat'l Rd              417
# 12           Alabang - GMA via National Road              191
# 13        Alabang - GMA via South Expressway               33
# ...

# %%
puj_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Route_Name        268 non-null    object
#  1   Franchise_Count   268 non-null    int64
#  2   Authorized_Units  268 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 6.4+ KB

# %%
traveller_df = pd.read_csv('data/2012_dot_list_reg_travellers_in_ph.csv')
traveller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   region              342 non-null    object
#  1   province_or_city    337 non-null    object
#  2   foreign_travelers   336 non-null    object
#  3   overseas_filipino   329 non-null    object
#  4   domestic_travelers  336 non-null    object
#  5   total_2012          337 non-null    object
# dtypes: object(6)
# memory usage: 16.2+ KB

# %%
traveller_df
# Out:
#                                                 region  \
# 0                        NCR (National Capital Region)
# 1                        NCR (National Capital Region)
# 2                        NCR (National Capital Region)
# 3                        NCR (National Capital Region)
# 4                        NCR (National Capital Region)
# ..                                                 ...
# 338  DISTRIBUTION OF REGIONAL TRAVELLERS IN THE PHI...
# 339                              January-December 2012
# 340  Source of Data:  Accommodation Establishments ...
# 341  Prepared by:  Tourism Research and Statistics ...
# 342                                As of 7 August 2013
#
#                   province_or_city foreign_travelers overseas_filipino  \
# 0    NCR (National Capital Region)           1513402             20048
# 1                    Caloocan City                 -                 -
# 2                   Las Pinas City                 -                 -
# ...

# %%
albay_df = pd.read_csv('data/pagasanormvallegaspialbay1981-2010.csv')
albay_df
# Out:
#         month  rainfall_amount  rainfall_number_of_rd  temp_max  temp_min  \
# 0     January            311.7                     21      28.8      23.2
# 1    February            236.4                     15      29.3      23.2
# 2       March            193.8                     17      30.2      23.8
# 3       April            171.2                     15      31.6      24.7
# 4         May            186.6                     15      32.4      25.3
# 5        June            230.5                     17      32.2      25.1
# 6        July            259.8                     20      31.5      24.7
# 7      August            222.5                     18      31.5      24.8
# 8   September            285.9                     19      31.4      24.5
# 9     October            333.0                     21      31.0      24.2
# 10   November            480.3                     23      30.2      24.2
# 11   December            520.2                     23      29.1      23.7
# ...

# %%
climate_df = pd.read_csv('data/Table A- CC Expenditures in context of the Overall Budget_v2.1.csv')
climate_df
# Out:
#                                          department  \
# 0                         Department of Agriculture
# 1                         Department of Agriculture
# 2                         Department of Agriculture
# 3                         Department of Agriculture
# 4                         Department of Agriculture
# 5   Department of Environment and Natural Resources
# 6   Department of Environment and Natural Resources
# 7   Department of Environment and Natural Resources
# 8   Department of Environment and Natural Resources
# 9   Department of Environment and Natural Resources
# 10  Department of Environment and Natural Resources
# 11                          Department of Education
# 12                          Department of Education
# 13                          Department of Education
# 14                    Department of Foreign Affairs
# 15      Department of Interior and Local Government
# 16      Department of Interior and Local Government
# ...

# %%
up_df = pd.read_csv('data/UP_StudEnrolmentAY1718_0.csv', encoding='latin')
up_df
# Out:
#    constituent_university education_level  count
# 0                 Diliman           Basic   1415
# 1                 Diliman   Undergraduate  14134
# 2                 Diliman        Graduate  10713
# 3               Los Baños           Basic    729
# 4               Los Baños   Undergraduate   8385
# 5               Los Baños        Graduate  10713
# 6                  Manila           Basic      0
# 7                  Manila   Undergraduate   3151
# 8                  Manila        Graduate   1790
# 9                 Visayas           Basic    511
# 10                Visayas   Undergraduate   2433
# 11                Visayas        Graduate    680
# 12        Open University           Basic      0
# 13        Open University   Undergraduate    780
# 14        Open University        Graduate   2905
# 15               Mindanao           Basic      0
# 16               Mindanao   Undergraduate    741
# 17               Mindanao        Graduate    150
# ...

# %%
up_prog_df = pd.read_csv('data/UP_ProgPerEducLevelAY1718_0.csv', encoding='latin')
up_prog_df
# Out:
#    constituent_university education_level              type  count
# 0                 Diliman   Undergraduate    Pre-Bachelor's      6
# 1                 Diliman   Undergraduate     Baccalaureate     71
# 2                 Diliman        Graduate   Post-Bachelor's     14
# 3                 Diliman        Graduate  Medicine and Law      1
# 4                 Diliman        Graduate          Master's     95
# 5                 Diliman        Graduate          Doctoral     49
# 6               Los Baños   Undergraduate    Pre-Bachelor's      1
# 7               Los Baños   Undergraduate     Baccalaureate     29
# 8               Los Baños        Graduate   Post-Bachelor's      0
# 9               Los Baños        Graduate  Medicine and Law      0
# 10              Los Baños        Graduate          Master's     57
# 11              Los Baños        Graduate          Doctoral     31
# 12                 Manila   Undergraduate    Pre-Bachelor's      2
# ...

# %%
up_disc_df = pd.read_csv('data/UP_ProgPerDiscAY1718_0.csv', encoding='latin')
up_disc_df
# Out:
#     constituent_university education_level                 discipline  count
# 0                  Diliman   Undergraduate    Science and Engineering     25
# 1                  Diliman        Graduate    Science and Engineering     62
# 2                  Diliman   Undergraduate  Agriculture and Fisheries      0
# 3                  Diliman        Graduate  Agriculture and Fisheries      0
# 4                  Diliman   Undergraduate            Social Sciences     18
# ..                     ...             ...                        ...    ...
# 107                   Cebu        Graduate                  Education      1
# 108                   Cebu   Undergraduate                        Law      0
# 109                   Cebu        Graduate                        Law      0
# 110                   Cebu   Undergraduate           Arts and Letters      3
# 111                   Cebu        Graduate           Arts and Letters      0
#
# [112 rows x 4 columns]

# %%
xperto_active_df = pd.read_csv('data/xperto_1_day_active_20201001-20210211.csv')
xperto_active_df
# Out:
#     Day Index                  Date Range    Segment  1 Day Active Users
# 0     10/1/20  Oct 1, 2020 - Feb 11, 2021  All Users                  94
# 1     10/1/20  Oct 1, 2020 - Feb 11, 2021  New Users                  78
# 2     10/2/20  Oct 1, 2020 - Feb 11, 2021  All Users                  51
# 3     10/2/20  Oct 1, 2020 - Feb 11, 2021  New Users                  37
# 4     10/3/20  Oct 1, 2020 - Feb 11, 2021  All Users                  26
# ..        ...                         ...        ...                 ...
# 263    2/9/21  Oct 1, 2020 - Feb 11, 2021  New Users                   9
# 264   2/10/21  Oct 1, 2020 - Feb 11, 2021  All Users                  17
# 265   2/10/21  Oct 1, 2020 - Feb 11, 2021  New Users                  12
# 266   2/11/21  Oct 1, 2020 - Feb 11, 2021  All Users                   8
# 267   2/11/21  Oct 1, 2020 - Feb 11, 2021  New Users                   2
#
# [268 rows x 4 columns]

# %%
manila_df = pd.read_csv('data/Manila_Edgelist.csv')
manila_df
# Out:
#                XCoord        YCoord  START_NODE  END_NODE    EDGE       LENGTH
# 0       316115.282629  1.545193e+06           1         2       1   345.590492
# 1       316354.264052  1.545431e+06           2         1       1   345.590492
# 2       314880.381537  1.545364e+06           3         4       2  1830.520662
# 3       313784.549758  1.544797e+06           4         3       2  1830.520662
# 4       316388.322404  1.545464e+06           5         6       3   426.250342
# ...               ...           ...         ...       ...     ...          ...
# 657773  287625.418694  1.625028e+06      657229    657227  328615     8.340055
# 657774  287625.418694  1.625028e+06      657229    657231  328616    25.126948
# 657775  287607.354993  1.625046e+06      657231    657229  328616    25.126948
# 657776  287607.354993  1.625046e+06      657231    518437  328617   184.782649
# 657777  295635.166970  1.626077e+06      657237    524503  328619   618.594933
#
# ...
